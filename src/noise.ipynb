# %% [markdown]
# # Noise, noise and more noise

# %% [markdown]
# ## 1. Noise model

# %% [markdown]
# We define a function `add_noise` that will apply Pauli operators to a given `QuantumCircuit` based on the probabilities
# $\alpha$ and $\beta$. First we need to define our Pauli operators, to do this we simply create a set of wrapper functions that will apply the specified gate:

# %%
from qiskit import QuantumCircuit

circuit = QuantumCircuit(2)
circuit.h(0)

circuit.draw('mpl')

# %%
from noise import add_pauli_noise

noisy_circuit = add_pauli_noise(circuit, 0.3, 0.78)
noisy_circuit.draw('mpl')

# %% [markdown]
# ## Decompose into basis

# %%
from decompose_basis import decompose_into_basis

basis_circuit = decompose_into_basis(circuit)
basis_circuit.draw('mpl')

# %% [markdown]
# ## Quantum sum

# %%
from quantum_sum import quantum_sum

sum_circuit = quantum_sum(1,1)
sum_circuit.draw('mpl')

# %% [markdown]
# # Run simulation

# %%
from run import main

main()
